# %% [markdown]
# <a href="https://colab.research.google.com/github/Nov05/Udacity-Python-28-Days/blob/master/notebooks/2019_10_08_Lesson_15_Web_Crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# created by nov05 on 2019-10-08

# %%
import requests
response = requests.get('https://en.wikipedia.org/wiki/Dead_Parrot_sketch')
if response.status_code == 200:
    print(type(response.text))
    print(response.text[:200])
# Out:
# <class 'str'>
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Dead Parrot sketch - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCON

# %% [markdown]
# # BeautifulSoup
#
# Watch the video first
# https://youtu.be/dk7ESZXLnk4

# %%
from bs4 import BeautifulSoup
doc_html = response.text
soup = BeautifulSoup(doc_html, 'html.parser')
print(soup.title)
print(soup.title.name)
print(soup.title.string)
print(soup.title.parent.name)
# Out:
# <title>Dead Parrot sketch - Wikipedia</title>
# title
# Dead Parrot sketch - Wikipedia
# head

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Dead Parrot sketch - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.p
# Out:
# <p class="mw-empty-elt">
# </p>

# %%
soup.p.find_all('a')
# Out:
# []

# %%
soup.find(id='footer-poweredbyico')
# Out:
# <li id="footer-poweredbyico">
# <a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/></a> </li>

# %% [markdown]
# # Robots exclusion standard
#
# Robots.txt is a file which is usually placed in the root of any website. It decides whether crawlers are permitted or forbidden access to the web site.
#
# https://developer.mozilla.org/en-US/docs/Glossary/Robots.txt
#
# https://en.wikipedia.org/robots.txt

# %%
### pseudo code 
# 页面=一个随机起始页
# article_chain = []
# 而页面标题不是“哲学”，而且我们还没有发现循环：
#     将页面添加到 article_chain
#     下载页面内容
#     在内容中查找第一个链接
#     页面=该链接
#     暂停片刻
